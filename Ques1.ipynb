# %% [markdown]
# To Explore Supervised Machine Learning

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline
print("All modules are imported!!")
# Out:
# All modules are imported!!

# %%
dataset = "http://bit.ly/w-data"
df = pd.read_csv(dataset)
df.head(7)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88

# %%
df.plot(x='Hours', y='Scores', style='s')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours')  
plt.ylabel('Scores')  
plt.show()

# %%
X= df['Hours'].values
y= df['Scores'].values
X= X.reshape(-2,1)
y= y.reshape(-2,1)

# %%
#TRAINING THE DATA

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
ourmodel = LinearRegression()

# %% [markdown]
# Fitting the model

# %%
ourmodel.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
ourmodel.coef_
# Out:
# array([[9.77580339]])

# %%
Predict = ourmodel.predict(X_test)

# %%
import seaborn as sns
plt.figure(figsize=(10,20));
sns.regplot(X, y);
plt.xlabel('hours')
plt.ylabel("Scores")
plt.show();

# %%
from sklearn import metrics
print('mean ABSOLUTE error->:', metrics.mean_absolute_error(y_test, Predict))
print('Root mean square error->:', np.sqrt(metrics.mean_squared_error(y_test,Predict)))
# Out:
# mean ABSOLUTE error->: 4.399809444644845
# Root mean square error->: 4.790431324471608

# %%
ourmodel.predict([[9.25]])
# Out:
# array([[92.90985477]])
